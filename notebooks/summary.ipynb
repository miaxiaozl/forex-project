# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
growth = pd.read_csv('/Users/miaxiaozile/Downloads/$/forex-project/data/growth_pred.csv', index_col='Unnamed: 0')
inflation = pd.read_csv('/Users/miaxiaozile/Downloads/$/forex-project/data/inflation_pred.csv', index_col='Unnamed: 0')
interest = pd.read_csv('/Users/miaxiaozile/Downloads/$/forex-project/data/interest_pred.csv', index_col='Unnamed: 0')

# %%
# Load the actual data
actual_data = pd.read_csv('/Users/miaxiaozile/Downloads/$/forex-project/data/fx.csv').set_index('Unnamed: 0')
actual_data.index.name = "Date"
actual_data.index = pd.to_datetime(actual_data.index)
actual_data.index = actual_data.index

# %%
# Plot the historical actual values and the forecasted actual values
plt.figure(figsize=(10, 5))

# Plot historical data
plt.plot(actual_data.index, actual_data['USD/CNY Central Parity Rate'], label='Historical USD/CNY Central Parity Rate')

# Plot forecasted data
plt.plot(growth_filtered.index, growth_filtered['Forecasted USD/CNY Central Parity Rate'], linestyle='--', label='Growth - Forecasted USD/CNY Central Parity Rate')
plt.plot(inflation_filtered.index, inflation_filtered['Forecasted USD/CNY Central Parity Rate'], linestyle='--', label='Inflation - Forecasted USD/CNY Central Parity Rate')
plt.plot(interest_filtered.index, interest_filtered['Forecasted USD/CNY Central Parity Rate'], linestyle='--', label='Interest - Forecasted USD/CNY Central Parity Rate')

# Set major locator and formatter to display only the year
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Add legend, title, and labels
plt.legend()
plt.grid()
plt.title('Historical and Forecasted USD/CNY Central Parity Rate')
plt.xlabel('Date')
plt.ylabel('USD/CNY Central Parity Rate')
plt.show()
